# %%
# 必要なライブラリのインストール
# !pip install scikit-optimize pandas matplotlib
# Out:
# Collecting scikit-optimize
#   Downloading scikit_optimize-0.10.2-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.11/dist-packages (from scikit-optimize) (1.4.2)
# Collecting pyaml>=16.9 (from scikit-optimize)
#   Downloading pyaml-25.1.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: numpy>=1.20.3 in /usr/local/lib/python3.11/dist-packages (from scikit-optimize) (2.0.2)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-optimize) (1.15.2)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-optimize) (1.6.1)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.11/dist-packages (from scikit-optimize) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from pyaml>=16.9->scikit-optimize) (6.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.0.0->scikit-optimize) (3.6.0)
# Downloading scikit_optimize-0.10.2-py2.py3-none-any.whl (107 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.8/107.8 kB 2.6 MB/s eta 0:00:00
# Downloading pyaml-25.1.0-py3-none-any.whl (26 kB)
# Installing collected packages: pyaml, scikit-optimize
# Successfully installed pyaml-25.1.0 scikit-optimize-0.10.2

# %%
from skopt import gp_minimize
from skopt.space import Real
from skopt.utils import use_named_args
from skopt.learning import GaussianProcessRegressor
from skopt.callbacks import EarlyStopper
import datetime
from sklearn.gaussian_process.kernels import RBF, Matern, WhiteKernel, ConstantKernel as C
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt
import os

# %% [markdown]
# #**カーネル関数デフォルト - 初期値だけ25,5でそれ以降から最適化・集中度9.8以上で終了**

# %%
# 🔧 探索空間の定義
space = [
    Real(15, 60, name="work_duration"),    # 作業時間（分）
    Real(3, 20, name="break_duration"),    # 休憩時間（分）
]

# 📦 ログファイルの初期化
log_file = "pomodoro_optimization_log.csv"
if not os.path.exists(log_file):
    pd.DataFrame(columns=["datetime", "work_duration", "break_duration", "focus_score"]).to_csv(log_file, index=False)

def simulate_focus_score(work_duration, break_duration):
    # 理想値との差を取ってスコアを下げる（理想：作業30分、休憩7分）
    work_penalty = abs(work_duration - 30) / 6     # ±6分ずれるごとに1点減点
    break_penalty = abs(break_duration - 7) / 2.5  # ±2.5分ずれるごとに1点減点

    base_score = 10 - (work_penalty + break_penalty)

    # ノイズを追加（±0.5程度のブレ）
    noise = np.random.normal(0, 0.5)
    score = base_score + noise

    # スコアは1〜10にクリップ
    return float(np.clip(score, 1, 10))


# 🧠 最適化する目的関数
@use_named_args(space)
def objective(when=None, **params):
    print(f"\n🕒 ポモドーロ設定を提案します:")
    print(f"👉 作業時間: {params['work_duration']:.1f}分")
    print(f"👉 休憩時間: {params['break_duration']:.1f}分")

    # 🔀 擬似的に集中度をシミュレート
    score = simulate_focus_score(params["work_duration"], params["break_duration"])
    print(f"✨ 自動生成された集中度スコア: {score:.2f}")
    if when is None:
      when = datetime.now()
    print(f"✨ 完了した時間: {when}")

    # ログに保存
    new_entry = {
        "datetime": datetime.now(),
        "work_duration": params["work_duration"],
        "break_duration": params["break_duration"],
        "focus_score": score
    }
    df = pd.read_csv(log_file)
    df = pd.concat([df, pd.DataFrame([new_entry])], ignore_index=True)
    df.to_csv(log_file, index=False)

    return -score

TARGET_SCORE = 9.8

# コールバック関数
def call_back(res):
    current_best = -res.fun
    if current_best >= TARGET_SCORE:
      return True
    return False

initial_point = [25, 5]
initial_score = simulate_focus_score(25, 5)

# 🔁 最適化の実行
result = gp_minimize(
    func=objective,
    dimensions=space,
    n_calls=1000,
    n_initial_points=1,
    x0=[initial_point],
    y0=[initial_score],
    random_state=42,
    verbose=True,
    callback=[call_back]
)

# 📊 結果の可視化
print("\n✅ 最適な設定（集中度最大）:")
print(f"作業時間: {result.x[0]:.1f}分")
print(f"休憩時間: {result.x[1]:.1f}分")
print(f"最大集中度: {-result.fun:.1f}")

# 収束プロット
from skopt.plots import plot_convergence
plot_convergence(result)
plt.show()
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 0.0002
# Function value obtained: 8.2085
# Current minimum: 8.2085
# Iteration No: 2 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 50.8分
# 👉 休憩時間: 6.1分
# ✨ 自動生成された集中度スコア: 6.53
# ✨ 完了した時間: 2025-04-30 13:22:16.492875
# Iteration No: 2 ended. Search finished for the next optimal point.
# Time taken: 0.1409
# Function value obtained: -6.5275
# Current minimum: -6.5275
# Iteration No: 3 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 50.8分
# 👉 休憩時間: 6.8分
# ✨ 自動生成された集中度スコア: 7.40
# ✨ 完了した時間: 2025-04-30 13:22:16.633467
# <ipython-input-4-737e34649e3a>:49: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, pd.DataFrame([new_entry])], ignore_index=True)
# Iteration No: 3 ended. Search finished for the next optimal point.
# Time taken: 0.2911
# Function value obtained: -7.3964
# Current minimum: -7.3964
# Iteration No: 4 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 50.0分
# 👉 休憩時間: 20.0分
# ✨ 自動生成された集中度スコア: 1.48
# ✨ 完了した時間: 2025-04-30 13:22:16.924918
# Iteration No: 4 ended. Search finished for the next optimal point.
# Time taken: 0.2831
# Function value obtained: -1.4848
# Current minimum: -7.3964
# Iteration No: 5 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 50.8分
# 👉 休憩時間: 7.0分
# ✨ 自動生成された集中度スコア: 6.93
# ✨ 完了した時間: 2025-04-30 13:22:17.208409
# Iteration No: 5 ended. Search finished for the next optimal point.
# Time taken: 0.3313
# Function value obtained: -6.9327
# Current minimum: -7.3964
# Iteration No: 6 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 50.8分
# 👉 休憩時間: 20.0分
# ✨ 自動生成された集中度スコア: 1.90
# ✨ 完了した時間: 2025-04-30 13:22:17.539994
# Iteration No: 6 ended. Search finished for the next optimal point.
# Time taken: 0.1608
# Function value obtained: -1.9012
# Current minimum: -7.3964
# Iteration No: 7 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 52.6分
# 👉 休憩時間: 8.7分
# ✨ 自動生成された集中度スコア: 5.10
# ✨ 完了した時間: 2025-04-30 13:22:17.700825
# Iteration No: 7 ended. Search finished for the next optimal point.
# Time taken: 0.2030
# Function value obtained: -5.0958
# Current minimum: -7.3964
# Iteration No: 8 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 49.2分
# 👉 休憩時間: 3.9分
# ✨ 自動生成された集中度スコア: 5.81
# ✨ 完了した時間: 2025-04-30 13:22:17.904099
# Iteration No: 8 ended. Search finished for the next optimal point.
# Time taken: 1.0325
# Function value obtained: -5.8090
# Current minimum: -7.3964
# Iteration No: 9 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 49.1分
# 👉 休憩時間: 7.5分
# ✨ 自動生成された集中度スコア: 6.71
# ✨ 完了した時間: 2025-04-30 13:22:18.936690
# Iteration No: 9 ended. Search finished for the next optimal point.
# Time taken: 0.4042
# Function value obtained: -6.7094
# Current minimum: -7.3964
# Iteration No: 10 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 50.1分
# 👉 休憩時間: 8.7分
# ✨ 自動生成された集中度スコア: 5.49
# ✨ 完了した時間: 2025-04-30 13:22:19.341133
# Iteration No: 10 ended. Search finished for the next optimal point.
# Time taken: 0.4329
# Function value obtained: -5.4905
# Current minimum: -7.3964
# Iteration No: 11 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 60.0分
# 👉 休憩時間: 3.0分
# ✨ 自動生成された集中度スコア: 3.38
# ✨ 完了した時間: 2025-04-30 13:22:19.774133
# Iteration No: 11 ended. Search finished for the next optimal point.
# Time taken: 0.7517
# Function value obtained: -3.3754
# Current minimum: -7.3964
# Iteration No: 12 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 15.0分
# 👉 休憩時間: 20.0分
# ✨ 自動生成された集中度スコア: 1.91
# ✨ 完了した時間: 2025-04-30 13:22:20.526134
# Iteration No: 12 ended. Search finished for the next optimal point.
# Time taken: 0.1726
# Function value obtained: -1.9115
# Current minimum: -7.3964
# Iteration No: 13 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 47.9分
# 👉 休憩時間: 6.3分
# ✨ 自動生成された集中度スコア: 6.75
# ✨ 完了した時間: 2025-04-30 13:22:20.698812
# Iteration No: 13 ended. Search finished for the next optimal point.
# Time taken: 0.1503
# Function value obtained: -6.7463
# Current minimum: -7.3964
# Iteration No: 14 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 60.0分
# 👉 休憩時間: 20.0分
# ✨ 自動生成された集中度スコア: 1.00
# ✨ 完了した時間: 2025-04-30 13:22:20.849505
# Iteration No: 14 ended. Search finished for the next optimal point.
# Time taken: 0.2239
# Function value obtained: -1.0000
# Current minimum: -7.3964
# Iteration No: 15 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 31.4分
# 👉 休憩時間: 20.0分
# ✨ 自動生成された集中度スコア: 4.60
# ✨ 完了した時間: 2025-04-30 13:22:21.073663
# Iteration No: 15 ended. Search finished for the next optimal point.
# Time taken: 0.2299
# Function value obtained: -4.6037
# Current minimum: -7.3964
# Iteration No: 16 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 35.9分
# 👉 休憩時間: 15.4分
# ✨ 自動生成された集中度スコア: 5.70
# ✨ 完了した時間: 2025-04-30 13:22:21.303897
# Iteration No: 16 ended. Search finished for the next optimal point.
# Time taken: 0.6167
# Function value obtained: -5.7019
# Current minimum: -7.3964
# Iteration No: 17 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 28.5分
# 👉 休憩時間: 16.1分
# ✨ 自動生成された集中度スコア: 6.02
# ✨ 完了した時間: 2025-04-30 13:22:21.920765
# Iteration No: 17 ended. Search finished for the next optimal point.
# Time taken: 0.2317
# Function value obtained: -6.0171
# Current minimum: -7.3964
# Iteration No: 18 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 31.8分
# 👉 休憩時間: 13.3分
# ✨ 自動生成された集中度スコア: 8.01
# ✨ 完了した時間: 2025-04-30 13:22:22.152703
# Iteration No: 18 ended. Search finished for the next optimal point.
# Time taken: 0.3322
# Function value obtained: -8.0063
# Current minimum: -8.0063
# Iteration No: 19 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 30.9分
# 👉 休憩時間: 13.2分
# ✨ 自動生成された集中度スコア: 6.91
# ✨ 完了した時間: 2025-04-30 13:22:22.485026
# Iteration No: 19 ended. Search finished for the next optimal point.
# Time taken: 0.2710
# Function value obtained: -6.9090
# Current minimum: -8.0063
# Iteration No: 20 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 35.3分
# 👉 休憩時間: 12.6分
# ✨ 自動生成された集中度スコア: 7.11
# ✨ 完了した時間: 2025-04-30 13:22:22.756225
# Iteration No: 20 ended. Search finished for the next optimal point.
# Time taken: 0.2031
# Function value obtained: -7.1090
# Current minimum: -8.0063
# Iteration No: 21 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 15.0分
# 👉 休憩時間: 13.9分
# ✨ 自動生成された集中度スコア: 4.21
# ✨ 完了した時間: 2025-04-30 13:22:22.959355
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 0.2197
# Function value obtained: -4.2089
# Current minimum: -8.0063
# Iteration No: 22 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 27.3分
# 👉 休憩時間: 13.7分
# ✨ 自動生成された集中度スコア: 6.59
# ✨ 完了した時間: 2025-04-30 13:22:23.179394
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 0.2095
# Function value obtained: -6.5889
# Current minimum: -8.0063
# Iteration No: 23 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 38.6分
# 👉 休憩時間: 10.7分
# ✨ 自動生成された集中度スコア: 6.99
# ✨ 完了した時間: 2025-04-30 13:22:23.388965
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 0.2105
# Function value obtained: -6.9924
# Current minimum: -8.0063
# Iteration No: 24 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 33.0分
# 👉 休憩時間: 11.7分
# ✨ 自動生成された集中度スコア: 7.56
# ✨ 完了した時間: 2025-04-30 13:22:23.599601
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 0.2175
# Function value obtained: -7.5550
# Current minimum: -8.0063
# Iteration No: 25 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 32.9分
# 👉 休憩時間: 11.7分
# ✨ 自動生成された集中度スコア: 7.64
# ✨ 完了した時間: 2025-04-30 13:22:23.817352
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 0.2345
# Function value obtained: -7.6420
# Current minimum: -8.0063
# Iteration No: 26 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 34.6分
# 👉 休憩時間: 12.3分
# ✨ 自動生成された集中度スコア: 6.51
# ✨ 完了した時間: 2025-04-30 13:22:24.052137
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 0.2494
# Function value obtained: -6.5067
# Current minimum: -8.0063
# Iteration No: 27 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 41.4分
# 👉 休憩時間: 8.5分
# ✨ 自動生成された集中度スコア: 7.89
# ✨ 完了した時間: 2025-04-30 13:22:24.301791
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 0.3419
# Function value obtained: -7.8920
# Current minimum: -8.0063
# Iteration No: 28 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 41.6分
# 👉 休憩時間: 8.4分
# ✨ 自動生成された集中度スコア: 7.51
# ✨ 完了した時間: 2025-04-30 13:22:24.643845
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 0.2597
# Function value obtained: -7.5074
# Current minimum: -8.0063
# Iteration No: 29 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 38.4分
# 👉 休憩時間: 9.3分
# ✨ 自動生成された集中度スコア: 8.17
# ✨ 完了した時間: 2025-04-30 13:22:24.903572
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 0.2665
# Function value obtained: -8.1656
# Current minimum: -8.1656
# Iteration No: 30 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 37.4分
# 👉 休憩時間: 9.4分
# ✨ 自動生成された集中度スコア: 8.46
# ✨ 完了した時間: 2025-04-30 13:22:25.170414
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 0.2707
# Function value obtained: -8.4602
# Current minimum: -8.4602
# Iteration No: 31 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 36.1分
# 👉 休憩時間: 9.5分
# ✨ 自動生成された集中度スコア: 8.57
# ✨ 完了した時間: 2025-04-30 13:22:25.441145
# Iteration No: 31 ended. Search finished for the next optimal point.
# Time taken: 0.2830
# Function value obtained: -8.5694
# Current minimum: -8.5694
# Iteration No: 32 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 35.3分
# 👉 休憩時間: 9.6分
# ✨ 自動生成された集中度スコア: 8.19
# ✨ 完了した時間: 2025-04-30 13:22:25.724260
# Iteration No: 32 ended. Search finished for the next optimal point.
# Time taken: 0.2585
# Function value obtained: -8.1904
# Current minimum: -8.5694
# Iteration No: 33 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 35.6分
# 👉 休憩時間: 9.5分
# ✨ 自動生成された集中度スコア: 7.99
# ✨ 完了した時間: 2025-04-30 13:22:25.982848
# Iteration No: 33 ended. Search finished for the next optimal point.
# Time taken: 0.2701
# Function value obtained: -7.9897
# Current minimum: -8.5694
# Iteration No: 34 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 37.2分
# 👉 休憩時間: 8.8分
# ✨ 自動生成された集中度スコア: 8.40
# ✨ 完了した時間: 2025-04-30 13:22:26.253077
# Iteration No: 34 ended. Search finished for the next optimal point.
# Time taken: 0.2682
# Function value obtained: -8.3968
# Current minimum: -8.5694
# Iteration No: 35 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 37.3分
# 👉 休憩時間: 8.8分
# ✨ 自動生成された集中度スコア: 8.24
# ✨ 完了した時間: 2025-04-30 13:22:26.521407
# Iteration No: 35 ended. Search finished for the next optimal point.
# Time taken: 0.3164
# Function value obtained: -8.2426
# Current minimum: -8.5694
# Iteration No: 36 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 37.4分
# 👉 休憩時間: 8.7分
# ✨ 自動生成された集中度スコア: 7.77
# ✨ 完了した時間: 2025-04-30 13:22:26.837921
# Iteration No: 36 ended. Search finished for the next optimal point.
# Time taken: 0.2830
# Function value obtained: -7.7749
# Current minimum: -8.5694
# Iteration No: 37 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 34.0分
# 👉 休憩時間: 9.9分
# ✨ 自動生成された集中度スコア: 7.80
# ✨ 完了した時間: 2025-04-30 13:22:27.121009
# Iteration No: 37 ended. Search finished for the next optimal point.
# Time taken: 0.3683
# Function value obtained: -7.7996
# Current minimum: -8.5694
# Iteration No: 38 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 37.6分
# 👉 休憩時間: 9.5分
# ✨ 自動生成された集中度スコア: 7.46
# ✨ 完了した時間: 2025-04-30 13:22:27.489456
# Iteration No: 38 ended. Search finished for the next optimal point.
# Time taken: 0.2972
# Function value obtained: -7.4587
# Current minimum: -8.5694
# Iteration No: 39 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 60.0分
# 👉 休憩時間: 6.9分
# ✨ 自動生成された集中度スコア: 4.21
# ✨ 完了した時間: 2025-04-30 13:22:27.786763
# Iteration No: 39 ended. Search finished for the next optimal point.
# Time taken: 0.3177
# Function value obtained: -4.2053
# Current minimum: -8.5694
# Iteration No: 40 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 39.2分
# 👉 休憩時間: 7.7分
# ✨ 自動生成された集中度スコア: 7.79
# ✨ 完了した時間: 2025-04-30 13:22:28.104623
# Iteration No: 40 ended. Search finished for the next optimal point.
# Time taken: 0.3109
# Function value obtained: -7.7892
# Current minimum: -8.5694
# Iteration No: 41 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 29.6分
# 👉 休憩時間: 10.8分
# ✨ 自動生成された集中度スコア: 8.76
# ✨ 完了した時間: 2025-04-30 13:22:28.415599
# Iteration No: 41 ended. Search finished for the next optimal point.
# Time taken: 0.3167
# Function value obtained: -8.7638
# Current minimum: -8.7638
# Iteration No: 42 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 27.9分
# 👉 休憩時間: 10.8分
# ✨ 自動生成された集中度スコア: 8.59
# ✨ 完了した時間: 2025-04-30 13:22:28.732379
# Iteration No: 42 ended. Search finished for the next optimal point.
# Time taken: 0.3236
# Function value obtained: -8.5918
# Current minimum: -8.7638
# Iteration No: 43 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 27.6分
# 👉 休憩時間: 10.8分
# ✨ 自動生成された集中度スコア: 8.22
# ✨ 完了した時間: 2025-04-30 13:22:29.056036
# Iteration No: 43 ended. Search finished for the next optimal point.
# Time taken: 0.3255
# Function value obtained: -8.2180
# Current minimum: -8.7638
# Iteration No: 44 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 30.0分
# 👉 休憩時間: 10.3分
# ✨ 自動生成された集中度スコア: 8.71
# ✨ 完了した時間: 2025-04-30 13:22:29.381680
# Iteration No: 44 ended. Search finished for the next optimal point.
# Time taken: 0.3242
# Function value obtained: -8.7065
# Current minimum: -8.7638
# Iteration No: 45 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 29.9分
# 👉 休憩時間: 10.2分
# ✨ 自動生成された集中度スコア: 9.23
# ✨ 完了した時間: 2025-04-30 13:22:29.705968
# Iteration No: 45 ended. Search finished for the next optimal point.
# Time taken: 0.3390
# Function value obtained: -9.2296
# Current minimum: -9.2296
# Iteration No: 46 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 23.5分
# 👉 休憩時間: 10.4分
# ✨ 自動生成された集中度スコア: 7.40
# ✨ 完了した時間: 2025-04-30 13:22:30.045096
# Iteration No: 46 ended. Search finished for the next optimal point.
# Time taken: 0.3416
# Function value obtained: -7.4022
# Current minimum: -9.2296
# Iteration No: 47 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 60.0分
# 👉 休憩時間: 14.6分
# ✨ 自動生成された集中度スコア: 1.53
# ✨ 完了した時間: 2025-04-30 13:22:30.386796
# Iteration No: 47 ended. Search finished for the next optimal point.
# Time taken: 0.6545
# Function value obtained: -1.5333
# Current minimum: -9.2296
# Iteration No: 48 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 30.1分
# 👉 休憩時間: 9.6分
# ✨ 自動生成された集中度スコア: 9.12
# ✨ 完了した時間: 2025-04-30 13:22:31.041441
# Iteration No: 48 ended. Search finished for the next optimal point.
# Time taken: 0.5928
# Function value obtained: -9.1228
# Current minimum: -9.2296
# Iteration No: 49 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 30.0分
# 👉 休憩時間: 9.6分
# ✨ 自動生成された集中度スコア: 8.85
# ✨ 完了した時間: 2025-04-30 13:22:31.634407
# Iteration No: 49 ended. Search finished for the next optimal point.
# Time taken: 0.5439
# Function value obtained: -8.8492
# Current minimum: -9.2296
# Iteration No: 50 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 29.9分
# 👉 休憩時間: 9.6分
# ✨ 自動生成された集中度スコア: 8.94
# ✨ 完了した時間: 2025-04-30 13:22:32.178568
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 0.5449
# Function value obtained: -8.9360
# Current minimum: -9.2296
# Iteration No: 51 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 29.8分
# 👉 休憩時間: 9.6分
# ✨ 自動生成された集中度スコア: 8.76
# ✨ 完了した時間: 2025-04-30 13:22:32.723739
# Iteration No: 51 ended. Search finished for the next optimal point.
# Time taken: 0.5990
# Function value obtained: -8.7621
# Current minimum: -9.2296
# Iteration No: 52 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 29.8分
# 👉 休憩時間: 9.6分
# ✨ 自動生成された集中度スコア: 9.70
# ✨ 完了した時間: 2025-04-30 13:22:33.322824
# Iteration No: 52 ended. Search finished for the next optimal point.
# Time taken: 0.9523
# Function value obtained: -9.7038
# Current minimum: -9.7038
# Iteration No: 53 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 15.0分
# 👉 休憩時間: 10.0分
# ✨ 自動生成された集中度スコア: 7.48
# ✨ 完了した時間: 2025-04-30 13:22:34.275149
# Iteration No: 53 ended. Search finished for the next optimal point.
# Time taken: 0.6725
# Function value obtained: -7.4783
# Current minimum: -9.7038
# Iteration No: 54 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 15.0分
# 👉 休憩時間: 11.4分
# ✨ 自動生成された集中度スコア: 6.23
# ✨ 完了した時間: 2025-04-30 13:22:34.947879
# Iteration No: 54 ended. Search finished for the next optimal point.
# Time taken: 0.5934
# Function value obtained: -6.2318
# Current minimum: -9.7038
# Iteration No: 55 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 27.2分
# 👉 休憩時間: 9.1分
# ✨ 自動生成された集中度スコア: 8.67
# ✨ 完了した時間: 2025-04-30 13:22:35.541496
# Iteration No: 55 ended. Search finished for the next optimal point.
# Time taken: 0.5660
# Function value obtained: -8.6717
# Current minimum: -9.7038
# Iteration No: 56 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 15.0分
# 👉 休憩時間: 8.5分
# ✨ 自動生成された集中度スコア: 7.59
# ✨ 完了した時間: 2025-04-30 13:22:36.107517
# Iteration No: 56 ended. Search finished for the next optimal point.
# Time taken: 0.7042
# Function value obtained: -7.5911
# Current minimum: -9.7038
# Iteration No: 57 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 60.0分
# 👉 休憩時間: 11.2分
# ✨ 自動生成された集中度スコア: 3.04
# ✨ 完了した時間: 2025-04-30 13:22:36.811836
# Iteration No: 57 ended. Search finished for the next optimal point.
# Time taken: 0.5973
# Function value obtained: -3.0398
# Current minimum: -9.7038
# Iteration No: 58 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 46.8分
# 👉 休憩時間: 13.3分
# ✨ 自動生成された集中度スコア: 5.46
# ✨ 完了した時間: 2025-04-30 13:22:37.409280
# Iteration No: 58 ended. Search finished for the next optimal point.
# Time taken: 0.5866
# Function value obtained: -5.4592
# Current minimum: -9.7038
# Iteration No: 59 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 15.0分
# 👉 休憩時間: 16.9分
# ✨ 自動生成された集中度スコア: 3.20
# ✨ 完了した時間: 2025-04-30 13:22:37.996102
# Iteration No: 59 ended. Search finished for the next optimal point.
# Time taken: 0.5958
# Function value obtained: -3.2033
# Current minimum: -9.7038
# Iteration No: 60 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 30.9分
# 👉 休憩時間: 8.8分
# ✨ 自動生成された集中度スコア: 9.13
# ✨ 完了した時間: 2025-04-30 13:22:38.592010
# Iteration No: 60 ended. Search finished for the next optimal point.
# Time taken: 0.6323
# Function value obtained: -9.1328
# Current minimum: -9.7038
# Iteration No: 61 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 24.0分
# 👉 休憩時間: 9.0分
# ✨ 自動生成された集中度スコア: 8.02
# ✨ 完了した時間: 2025-04-30 13:22:39.224465
# Iteration No: 61 ended. Search finished for the next optimal point.
# Time taken: 0.6967
# Function value obtained: -8.0217
# Current minimum: -9.7038
# Iteration No: 62 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 31.1分
# 👉 休憩時間: 8.8分
# ✨ 自動生成された集中度スコア: 9.63
# ✨ 完了した時間: 2025-04-30 13:22:39.921248
# Iteration No: 62 ended. Search finished for the next optimal point.
# Time taken: 0.5550
# Function value obtained: -9.6332
# Current minimum: -9.7038
# Iteration No: 63 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 31.1分
# 👉 休憩時間: 8.7分
# ✨ 自動生成された集中度スコア: 8.19
# ✨ 完了した時間: 2025-04-30 13:22:40.476484
# Iteration No: 63 ended. Search finished for the next optimal point.
# Time taken: 0.6023
# Function value obtained: -8.1949
# Current minimum: -9.7038
# Iteration No: 64 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 37.5分
# 👉 休憩時間: 17.9分
# ✨ 自動生成された集中度スコア: 5.14
# ✨ 完了した時間: 2025-04-30 13:22:41.078855
# Iteration No: 64 ended. Search finished for the next optimal point.
# Time taken: 0.5396
# Function value obtained: -5.1413
# Current minimum: -9.7038
# Iteration No: 65 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 29.9分
# 👉 休憩時間: 9.4分
# ✨ 自動生成された集中度スコア: 8.84
# ✨ 完了した時間: 2025-04-30 13:22:41.618621
# Iteration No: 65 ended. Search finished for the next optimal point.
# Time taken: 0.5775
# Function value obtained: -8.8415
# Current minimum: -9.7038
# Iteration No: 66 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 30.0分
# 👉 休憩時間: 9.4分
# ✨ 自動生成された集中度スコア: 9.31
# ✨ 完了した時間: 2025-04-30 13:22:42.196350
# Iteration No: 66 ended. Search finished for the next optimal point.
# Time taken: 0.6217
# Function value obtained: -9.3065
# Current minimum: -9.7038
# Iteration No: 67 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 29.9分
# 👉 休憩時間: 9.4分
# ✨ 自動生成された集中度スコア: 8.50
# ✨ 完了した時間: 2025-04-30 13:22:42.818345
# Iteration No: 67 ended. Search finished for the next optimal point.
# Time taken: 0.6743
# Function value obtained: -8.5026
# Current minimum: -9.7038
# Iteration No: 68 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 30.0分
# 👉 休憩時間: 9.4分
# ✨ 自動生成された集中度スコア: 7.93
# ✨ 完了した時間: 2025-04-30 13:22:43.492838
# Iteration No: 68 ended. Search finished for the next optimal point.
# Time taken: 0.7074
# Function value obtained: -7.9256
# Current minimum: -9.7038
# Iteration No: 69 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 29.5分
# 👉 休憩時間: 9.5分
# ✨ 自動生成された集中度スコア: 8.83
# ✨ 完了した時間: 2025-04-30 13:22:44.200440
# Iteration No: 69 ended. Search finished for the next optimal point.
# Time taken: 0.5694
# Function value obtained: -8.8312
# Current minimum: -9.7038
# Iteration No: 70 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 30.8分
# 👉 休憩時間: 9.2分
# ✨ 自動生成された集中度スコア: 8.67
# ✨ 完了した時間: 2025-04-30 13:22:44.769906
# Iteration No: 70 ended. Search finished for the next optimal point.
# Time taken: 1.2941
# Function value obtained: -8.6721
# Current minimum: -9.7038
# Iteration No: 71 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 29.1分
# 👉 休憩時間: 9.6分
# ✨ 自動生成された集中度スコア: 8.63
# ✨ 完了した時間: 2025-04-30 13:22:46.064132
# Iteration No: 71 ended. Search finished for the next optimal point.
# Time taken: 0.6554
# Function value obtained: -8.6279
# Current minimum: -9.7038
# Iteration No: 72 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 31.2分
# 👉 休憩時間: 9.1分
# ✨ 自動生成された集中度スコア: 8.72
# ✨ 完了した時間: 2025-04-30 13:22:46.719663
# Iteration No: 72 ended. Search finished for the next optimal point.
# Time taken: 0.6051
# Function value obtained: -8.7223
# Current minimum: -9.7038
# Iteration No: 73 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 29.2分
# 👉 休憩時間: 9.7分
# ✨ 自動生成された集中度スコア: 9.04
# ✨ 完了した時間: 2025-04-30 13:22:47.325032
# Iteration No: 73 ended. Search finished for the next optimal point.
# Time taken: 0.6121
# Function value obtained: -9.0366
# Current minimum: -9.7038
# Iteration No: 74 started. Searching for the next optimal point.
#
# 🕒 ポモドーロ設定を提案します:
# 👉 作業時間: 29.2分
# 👉 休憩時間: 9.7分
# ✨ 自動生成された集中度スコア: 9.82
# ✨ 完了した時間: 2025-04-30 13:22:47.937167
# Iteration No: 74 ended. Search finished for the next optimal point.
# Time taken: 0.6071
# Function value obtained: -9.8228
# Current minimum: -9.8228
# Iteration No: 75 started. Searching for the next optimal point.
#
# ✅ 最適な設定（集中度最大）:
# 作業時間: 29.2分
# 休憩時間: 9.7分
# 最大集中度: 9.8

# %% [markdown]
# #**カーネル関数を合成した場合**

# %%
# 🔧 探索空間の定義
space = [
    Real(15, 60, name="work_duration"),    # 作業時間（分）
    Real(3, 20, name="break_duration"),    # 休憩時間（分）
]

# 📦 ログファイルの初期化
log_file = "pomodoro_optimization_log.csv"
if not os.path.exists(log_file):
    pd.DataFrame(columns=["datetime", "work_duration", "break_duration", "focus_score"]).to_csv(log_file, index=False)

# 🎯 集中度スコアのリアルなモデル（理想からのズレ + ノイズ）
def simulate_focus_score(work_duration, break_duration):
    work_penalty = abs(work_duration - 30) / 6
    break_penalty = abs(break_duration - 7) / 2.5
    base_score = 10 - (work_penalty + break_penalty)
    noise = np.random.normal(0, 0.5)
    return float(np.clip(base_score + noise, 1, 10))

# 🧠 目的関数
@use_named_args(space)
def objective(**params):
    print(f"\n🕒 提案されたポモドーロ設定:")
    print(f"👉 作業時間: {params['work_duration']:.1f}分")
    print(f"👉 休憩時間: {params['break_duration']:.1f}分")
    score = simulate_focus_score(params["work_duration"], params["break_duration"])
    print(f"✨ 集中度スコア（自動生成）: {score:.2f}")

    # ログ保存
    new_entry = {
        "datetime": datetime.datetime.now(),
        "work_duration": params["work_duration"],
        "break_duration": params["break_duration"],
        "focus_score": score
    }
    df = pd.read_csv(log_file)
    df = pd.concat([df, pd.DataFrame([new_entry])], ignore_index=True)
    df.to_csv(log_file, index=False)

    return -score  # スコア最大化 → 最小化問題にするため符号反転

# 🔧 カスタム合成カーネル（滑らか + 粗さ + ノイズ + バイアス）
kernel = (RBF(length_scale=10.0) * Matern(length_scale=5.0, nu=1.5)) + WhiteKernel(noise_level=0.5) + C(1.0)

# 📈 GPRモデルにカスタムカーネルを組み込む
base_estimator = GaussianProcessRegressor(kernel=kernel, normalize_y=True, random_state=42)

# 🔁 ベイズ最適化の実行
from skopt import gp_minimize
result = gp_minimize(
    func=objective,
    dimensions=space,
    base_estimator=base_estimator,
    n_calls=50,
    n_initial_points=5,
    random_state=42,
    acq_optimizer="sampling",
    verbose=True
)

# 📊 最適結果の表示
print("\n✅ 最適なポモドーロ設定:")
print(f"作業時間: {result.x[0]:.1f}分")
print(f"休憩時間: {result.x[1]:.1f}分")
print(f"最大集中度: {-result.fun:.2f}")

# 🔍 収束プロット
from skopt.plots import plot_convergence
plot_convergence(result)
plt.tight_layout()
plt.show()
# Out:
# Iteration No: 1 started. Evaluating function at random point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 31.9分
# 👉 休憩時間: 19.2分
# ✨ 集中度スコア（自動生成）: 4.93
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 0.0060
# Function value obtained: -4.9263
# Current minimum: -4.9263
# Iteration No: 2 started. Evaluating function at random point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 47.9分
# 👉 休憩時間: 13.2分
# ✨ 集中度スコア（自動生成）: 4.69
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 0.0039
# Function value obtained: -4.6924
# Current minimum: -4.9263
# Iteration No: 3 started. Evaluating function at random point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 22.0分
# 👉 休憩時間: 5.7分
# ✨ 集中度スコア（自動生成）: 8.26
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 0.0038
# Function value obtained: -8.2575
# Current minimum: -8.2575
# Iteration No: 4 started. Evaluating function at random point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 17.6分
# 👉 休憩時間: 17.7分
# ✨ 集中度スコア（自動生成）: 4.48
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 0.0039
# Function value obtained: -4.4826
# Current minimum: -8.2575
# Iteration No: 5 started. Evaluating function at random point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 42.1分
# 👉 休憩時間: 15.0分
# ✨ 集中度スコア（自動生成）: 4.32
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 0.0674
# Function value obtained: -4.3198
# Current minimum: -8.2575
# Iteration No: 6 started. Searching for the next optimal point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 15.9分
# 👉 休憩時間: 18.1分
# ✨ 集中度スコア（自動生成）: 2.60
# Iteration No: 6 ended. Search finished for the next optimal point.
# Time taken: 0.0730
# Function value obtained: -2.5951
# Current minimum: -8.2575
# Iteration No: 7 started. Searching for the next optimal point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 21.1分
# 👉 休憩時間: 19.1分
# ✨ 集中度スコア（自動生成）: 3.60
# Iteration No: 7 ended. Search finished for the next optimal point.
# Time taken: 0.0806
# Function value obtained: -3.5983
# Current minimum: -8.2575
# Iteration No: 8 started. Searching for the next optimal point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 56.6分
# 👉 休憩時間: 13.7分
# ✨ 集中度スコア（自動生成）: 2.53
# Iteration No: 8 ended. Search finished for the next optimal point.
# Time taken: 0.1594
# Function value obtained: -2.5285
# Current minimum: -8.2575
# Iteration No: 9 started. Searching for the next optimal point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 24.1分
# 👉 休憩時間: 4.8分
# ✨ 集中度スコア（自動生成）: 8.90
# Iteration No: 9 ended. Search finished for the next optimal point.
# Time taken: 0.1597
# Function value obtained: -8.8979
# Current minimum: -8.8979
# Iteration No: 10 started. Searching for the next optimal point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 24.3分
# 👉 休憩時間: 3.9分
# ✨ 集中度スコア（自動生成）: 8.63
# Iteration No: 10 ended. Search finished for the next optimal point.
# Time taken: 0.1666
# Function value obtained: -8.6256
# Current minimum: -8.8979
# Iteration No: 11 started. Searching for the next optimal point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 33.1分
# 👉 休憩時間: 3.0分
# ✨ 集中度スコア（自動生成）: 6.93
# Iteration No: 11 ended. Search finished for the next optimal point.
# Time taken: 0.3004
# Function value obtained: -6.9318
# Current minimum: -8.8979
# Iteration No: 12 started. Searching for the next optimal point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 15.1分
# 👉 休憩時間: 3.1分
# ✨ 集中度スコア（自動生成）: 6.05
# Iteration No: 12 ended. Search finished for the next optimal point.
# Time taken: 0.1506
# Function value obtained: -6.0511
# Current minimum: -8.8979
# Iteration No: 13 started. Searching for the next optimal point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 26.0分
# 👉 休憩時間: 5.7分
# ✨ 集中度スコア（自動生成）: 8.70
# Iteration No: 13 ended. Search finished for the next optimal point.
# Time taken: 0.1711
# Function value obtained: -8.7044
# Current minimum: -8.8979
# Iteration No: 14 started. Searching for the next optimal point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 27.1分
# 👉 休憩時間: 7.2分
# ✨ 集中度スコア（自動生成）: 9.74
# Iteration No: 14 ended. Search finished for the next optimal point.
# Time taken: 0.3013
# Function value obtained: -9.7443
# Current minimum: -9.7443
# Iteration No: 15 started. Searching for the next optimal point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 27.9分
# 👉 休憩時間: 7.9分
# ✨ 集中度スコア（自動生成）: 9.62
# Iteration No: 15 ended. Search finished for the next optimal point.
# Time taken: 0.2494
# Function value obtained: -9.6190
# Current minimum: -9.7443
# Iteration No: 16 started. Searching for the next optimal point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 27.9分
# 👉 休憩時間: 7.9分
# ✨ 集中度スコア（自動生成）: 8.98
# Iteration No: 16 ended. Search finished for the next optimal point.
# Time taken: 0.2056
# Function value obtained: -8.9761
# Current minimum: -9.7443
# Iteration No: 17 started. Searching for the next optimal point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 25.9分
# 👉 休憩時間: 5.7分
# ✨ 集中度スコア（自動生成）: 7.25
# Iteration No: 17 ended. Search finished for the next optimal point.
# Time taken: 0.2467
# Function value obtained: -7.2466
# Current minimum: -9.7443
# Iteration No: 18 started. Searching for the next optimal point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 27.3分
# 👉 休憩時間: 8.2分
# ✨ 集中度スコア（自動生成）: 8.37
# Iteration No: 18 ended. Search finished for the next optimal point.
# Time taken: 0.3063
# Function value obtained: -8.3718
# Current minimum: -9.7443
# Iteration No: 19 started. Searching for the next optimal point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 27.7分
# 👉 休憩時間: 7.9分
# ✨ 集中度スコア（自動生成）: 9.74
# Iteration No: 19 ended. Search finished for the next optimal point.
# Time taken: 0.2398
# Function value obtained: -9.7394
# Current minimum: -9.7443
# Iteration No: 20 started. Searching for the next optimal point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 27.6分
# 👉 休憩時間: 7.9分
# ✨ 集中度スコア（自動生成）: 8.69
# Iteration No: 20 ended. Search finished for the next optimal point.
# Time taken: 0.2277
# Function value obtained: -8.6936
# Current minimum: -9.7443
# Iteration No: 21 started. Searching for the next optimal point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 27.9分
# 👉 休憩時間: 7.7分
# ✨ 集中度スコア（自動生成）: 10.00
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 0.3394
# Function value obtained: -10.0000
# Current minimum: -10.0000
# Iteration No: 22 started. Searching for the next optimal point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 28.4分
# 👉 休憩時間: 8.0分
# ✨ 集中度スコア（自動生成）: 10.00
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 0.2556
# Function value obtained: -10.0000
# Current minimum: -10.0000
# Iteration No: 23 started. Searching for the next optimal point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 28.8分
# 👉 休憩時間: 8.2分
# ✨ 集中度スコア（自動生成）: 9.75
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 0.2604
# Function value obtained: -9.7520
# Current minimum: -10.0000
# Iteration No: 24 started. Searching for the next optimal point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 28.7分
# 👉 休憩時間: 8.1分
# ✨ 集中度スコア（自動生成）: 9.57
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 0.2637
# Function value obtained: -9.5664
# Current minimum: -10.0000
# Iteration No: 25 started. Searching for the next optimal point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 28.8分
# 👉 休憩時間: 8.2分
# ✨ 集中度スコア（自動生成）: 9.07
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 0.2847
# Function value obtained: -9.0659
# Current minimum: -10.0000
# Iteration No: 26 started. Searching for the next optimal point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 29.2分
# 👉 休憩時間: 8.1分
# ✨ 集中度スコア（自動生成）: 9.23
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 0.2879
# Function value obtained: -9.2264
# Current minimum: -10.0000
# Iteration No: 27 started. Searching for the next optimal point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 29.1分
# 👉 休憩時間: 8.2分
# ✨ 集中度スコア（自動生成）: 9.87
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 0.2814
# Function value obtained: -9.8731
# Current minimum: -10.0000
# Iteration No: 28 started. Searching for the next optimal point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 29.4分
# 👉 休憩時間: 8.2分
# ✨ 集中度スコア（自動生成）: 8.49
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 0.2892
# Function value obtained: -8.4881
# Current minimum: -10.0000
# Iteration No: 29 started. Searching for the next optimal point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 28.6分
# 👉 休憩時間: 8.2分
# ✨ 集中度スコア（自動生成）: 9.50
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 0.3073
# Function value obtained: -9.5017
# Current minimum: -10.0000
# Iteration No: 30 started. Searching for the next optimal point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 28.7分
# 👉 休憩時間: 8.3分
# ✨ 集中度スコア（自動生成）: 8.61
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 0.4020
# Function value obtained: -8.6075
# Current minimum: -10.0000
# Iteration No: 31 started. Searching for the next optimal point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 28.3分
# 👉 休憩時間: 8.2分
# ✨ 集中度スコア（自動生成）: 8.76
# Iteration No: 31 ended. Search finished for the next optimal point.
# Time taken: 0.3124
# Function value obtained: -8.7553
# Current minimum: -10.0000
# Iteration No: 32 started. Searching for the next optimal point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 28.4分
# 👉 休憩時間: 8.0分
# ✨ 集中度スコア（自動生成）: 8.67
# Iteration No: 32 ended. Search finished for the next optimal point.
# Time taken: 0.4170
# Function value obtained: -8.6667
# Current minimum: -10.0000
# Iteration No: 33 started. Searching for the next optimal point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 28.5分
# 👉 休憩時間: 7.9分
# ✨ 集中度スコア（自動生成）: 9.07
# Iteration No: 33 ended. Search finished for the next optimal point.
# Time taken: 1.4590
# Function value obtained: -9.0717
# Current minimum: -10.0000
# Iteration No: 34 started. Searching for the next optimal point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 28.5分
# 👉 休憩時間: 8.0分
# ✨ 集中度スコア（自動生成）: 9.01
# Iteration No: 34 ended. Search finished for the next optimal point.
# Time taken: 0.5601
# Function value obtained: -9.0056
# Current minimum: -10.0000
# Iteration No: 35 started. Searching for the next optimal point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 28.1分
# 👉 休憩時間: 8.0分
# ✨ 集中度スコア（自動生成）: 8.74
# Iteration No: 35 ended. Search finished for the next optimal point.
# Time taken: 0.4917
# Function value obtained: -8.7399
# Current minimum: -10.0000
# Iteration No: 36 started. Searching for the next optimal point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 28.4分
# 👉 休憩時間: 7.9分
# ✨ 集中度スコア（自動生成）: 9.49
# Iteration No: 36 ended. Search finished for the next optimal point.
# Time taken: 0.3928
# Function value obtained: -9.4940
# Current minimum: -10.0000
# Iteration No: 37 started. Searching for the next optimal point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 28.6分
# 👉 休憩時間: 7.9分
# ✨ 集中度スコア（自動生成）: 9.69
# Iteration No: 37 ended. Search finished for the next optimal point.
# Time taken: 0.4463
# Function value obtained: -9.6950
# Current minimum: -10.0000
# Iteration No: 38 started. Searching for the next optimal point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 28.8分
# 👉 休憩時間: 7.9分
# ✨ 集中度スコア（自動生成）: 9.34
# Iteration No: 38 ended. Search finished for the next optimal point.
# Time taken: 0.4511
# Function value obtained: -9.3363
# Current minimum: -10.0000
# Iteration No: 39 started. Searching for the next optimal point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 29.0分
# 👉 休憩時間: 7.9分
# ✨ 集中度スコア（自動生成）: 10.00
# Iteration No: 39 ended. Search finished for the next optimal point.
# Time taken: 0.3510
# Function value obtained: -10.0000
# Current minimum: -10.0000
# Iteration No: 40 started. Searching for the next optimal point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 30.3分
# 👉 休憩時間: 7.3分
# ✨ 集中度スコア（自動生成）: 9.99
# Iteration No: 40 ended. Search finished for the next optimal point.
# Time taken: 0.4536
# Function value obtained: -9.9891
# Current minimum: -10.0000
# Iteration No: 41 started. Searching for the next optimal point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 29.9分
# 👉 休憩時間: 7.2分
# ✨ 集中度スコア（自動生成）: 10.00
# Iteration No: 41 ended. Search finished for the next optimal point.
# Time taken: 0.3691
# Function value obtained: -10.0000
# Current minimum: -10.0000
# Iteration No: 42 started. Searching for the next optimal point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 30.2分
# 👉 休憩時間: 7.2分
# ✨ 集中度スコア（自動生成）: 10.00
# Iteration No: 42 ended. Search finished for the next optimal point.
# Time taken: 0.3773
# Function value obtained: -10.0000
# Current minimum: -10.0000
# Iteration No: 43 started. Searching for the next optimal point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 30.2分
# 👉 休憩時間: 7.1分
# ✨ 集中度スコア（自動生成）: 9.99
# Iteration No: 43 ended. Search finished for the next optimal point.
# Time taken: 0.3952
# Function value obtained: -9.9887
# Current minimum: -10.0000
# Iteration No: 44 started. Searching for the next optimal point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 30.0分
# 👉 休憩時間: 7.3分
# ✨ 集中度スコア（自動生成）: 9.50
# Iteration No: 44 ended. Search finished for the next optimal point.
# Time taken: 0.3866
# Function value obtained: -9.5012
# Current minimum: -10.0000
# Iteration No: 45 started. Searching for the next optimal point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 29.6分
# 👉 休憩時間: 7.2分
# ✨ 集中度スコア（自動生成）: 10.00
# Iteration No: 45 ended. Search finished for the next optimal point.
# Time taken: 0.3996
# Function value obtained: -10.0000
# Current minimum: -10.0000
# Iteration No: 46 started. Searching for the next optimal point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 29.7分
# 👉 休憩時間: 7.2分
# ✨ 集中度スコア（自動生成）: 10.00
# Iteration No: 46 ended. Search finished for the next optimal point.
# Time taken: 0.4299
# Function value obtained: -10.0000
# Current minimum: -10.0000
# Iteration No: 47 started. Searching for the next optimal point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 30.0分
# 👉 休憩時間: 7.1分
# ✨ 集中度スコア（自動生成）: 10.00
# Iteration No: 47 ended. Search finished for the next optimal point.
# Time taken: 0.5177
# Function value obtained: -10.0000
# Current minimum: -10.0000
# Iteration No: 48 started. Searching for the next optimal point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 30.0分
# 👉 休憩時間: 7.4分
# ✨ 集中度スコア（自動生成）: 9.21
# Iteration No: 48 ended. Search finished for the next optimal point.
# Time taken: 0.5580
# Function value obtained: -9.2079
# Current minimum: -10.0000
# Iteration No: 49 started. Searching for the next optimal point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 29.7分
# 👉 休憩時間: 7.2分
# ✨ 集中度スコア（自動生成）: 9.50
# Iteration No: 49 ended. Search finished for the next optimal point.
# Time taken: 0.6411
# Function value obtained: -9.5000
# Current minimum: -10.0000
# Iteration No: 50 started. Searching for the next optimal point.
#
# 🕒 提案されたポモドーロ設定:
# 👉 作業時間: 29.5分
# 👉 休憩時間: 7.2分
# ✨ 集中度スコア（自動生成）: 9.77
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 0.5851
# Function value obtained: -9.7685
# Current minimum: -10.0000
#
# ✅ 最適なポモドーロ設定:
# 作業時間: 27.9分
# 休憩時間: 7.7分
# 最大集中度: 10.00
